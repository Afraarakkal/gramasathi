# %%
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# %%
# !pip install -U openai-whisper flask pyngrok ffmpeg-python
# Out:
# Requirement already satisfied: openai-whisper in /usr/local/lib/python3.12/dist-packages (20250625)
# Requirement already satisfied: flask in /usr/local/lib/python3.12/dist-packages (3.1.2)
# Requirement already satisfied: pyngrok in /usr/local/lib/python3.12/dist-packages (7.5.0)
# Requirement already satisfied: ffmpeg-python in /usr/local/lib/python3.12/dist-packages (0.2.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (10.8.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (0.60.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (2.0.2)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (0.12.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (2.9.0+cu126)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (4.67.2)
# Requirement already satisfied: triton>=2 in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (3.5.0)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from flask) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.12/dist-packages (from flask) (8.3.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from flask) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from flask) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from flask) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from flask) (3.1.5)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.12/dist-packages (from pyngrok) (6.0.3)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from ffmpeg-python) (1.0.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->openai-whisper) (0.43.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken->openai-whisper) (2025.11.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from tiktoken->openai-whisper) (2.32.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (3.6.1)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (1.11.1.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2026.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->openai-whisper) (1.3.0)

# %%
import whisper
import torch

torch.cuda.empty_cache()

model = whisper.load_model(
    "large",
    device="cuda",
)

# %%
# 3. Flask app
from flask import Flask, request, jsonify
import tempfile, os

app = Flask(__name__)

@app.route("/transcribe", methods=["POST"])
def transcribe():
    audio = request.files["audio"]

    with tempfile.NamedTemporaryFile(suffix=".ogg", delete=False) as tmp:
        audio.save(tmp.name)
        print("Audio received in Colab")

        result = model.transcribe(
            tmp.name,
            language="en",
            task="transcribe",
            beam_size=5,
            temperature=0,
        )

    os.remove(tmp.name)
    print("Transcription done")
    return jsonify({"text": result["text"]})

# %%
# 4. Ngrok tunnel
from pyngrok import ngrok
ngrok.set_auth_token("2y4JTpRoxwfc725Zl6xtYUth9RR_ofPkgedhBpxa5x2n2xLV")
public_url = ngrok.connect(5000)
print("PUBLIC URL:", public_url)
# Out:
# PUBLIC URL: NgrokTunnel: "https://33b8-34-87-17-167.ngrok-free.app" -> "http://localhost:5000"

# %%
app.run(port=5000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:37:40] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:37:45] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:37:55] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:38:19] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:39:56] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:40:20] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:41:37] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:42:10] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:43:03] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:43:24] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:43:47] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:44:01] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:44:29] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:44:45] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:45:00] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:45:38] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:47:08] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:48:31] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:48:50] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:49:12] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:49:40] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:49:54] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:50:42] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:51:34] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:53:11] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:54:19] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:55:42] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:56:06] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:56:32] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:57:07] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:57:39] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:57:42] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:58:01] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:58:16] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:58:28] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:58:34] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:58:40] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:59:09] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:59:40] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 09:59:48] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 10:00:01] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 10:00:39] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 10:00:50] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 10:01:04] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 10:01:13] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 10:02:16] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 10:02:35] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 10:03:10] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 10:03:26] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
# Audio received in Colab
# INFO:werkzeug:127.0.0.1 - - [09/Feb/2026 10:03:43] "POST /transcribe HTTP/1.1" 200 -
# Transcription done
